# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from starkhelium import wf_numerov

# %%
n = 10; l = 7
r, y = wf_numerov(n, l, n)

# plot
fig, ax = plt.subplots()
ax.plot(r, y)
plt.show()
